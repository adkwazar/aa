# %% [markdown]
# https://mathgene.usc.es/snipper4/

# %%
dane = read.csv("methylation_examples.csv", sep = ";")
head(dane)
# Out:
#   Age CR_1_CpG_9 CR_2_CpG_3 CR_4_CpG_27.28.29 CR_12_1_CpG_3 CR_13_CpG_2
# 1 59  0.370      0.535      0.210             0.485         0.180
# 2 32  0.265      0.715      0.135             0.290         0.320
# 3 31  0.305      0.725      0.155             0.270         0.345
# 4 31  0.280      0.670      0.170             0.290         0.420
# 5 28  0.250      0.700      0.140             0.330         0.350
# 6 32  0.310      0.690      0.155             0.320         0.370
#   CR_21_CpG_11 CR_23_CpG_3
# 1 0.455        0.415
# 2 0.710        0.500
# 3 0.735        0.550
# 4 0.730        0.580
# 5 0.670        0.515
# 6 0.790        0.450

# %%
summary(dane)
# Out:
#       Age          CR_1_CpG_9       CR_2_CpG_3     CR_4_CpG_27.28.29
#  Min.   :28.00   Min.   :0.2500   Min.   :0.4410   Min.   :0.1350
#  1st Qu.:47.50   1st Qu.:0.3850   1st Qu.:0.6030   1st Qu.:0.2000
#  Median :54.80   Median :0.4250   Median :0.6600   Median :0.2250
#  Mean   :54.12   Mean   :0.4219   Mean   :0.6455   Mean   :0.2248
#  3rd Qu.:61.90   3rd Qu.:0.4600   3rd Qu.:0.7150   3rd Qu.:0.2500
#  Max.   :69.30   Max.   :0.5650   Max.   :0.7800   Max.   :0.3400
#  CR_12_1_CpG_3     CR_13_CpG_2      CR_21_CpG_11     CR_23_CpG_3
#  Min.   :0.2700   Min.   :0.1100   Min.   :0.2500   Min.   :0.21
#  1st Qu.:0.3950   1st Qu.:0.1800   1st Qu.:0.4600   1st Qu.:0.40
#  Median :0.4400   Median :0.2300   Median :0.5550   Median :0.44
#  Mean   :0.4353   Mean   :0.2293   Mean   :0.5501   Mean   :0.43
#  3rd Qu.:0.4800   3rd Qu.:0.2750   3rd Qu.:0.6300   3rd Qu.:0.47
#  Max.   :0.5700   Max.   :0.4200   Max.   :0.8300   Max.   :0.60

# %%
m = lm(Age~., data = dane)
summary(m)
# Out:
# Call:
# lm(formula = Age ~ ., data = dane)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.015  -2.506  -0.401   2.832  13.807
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)        27.6686     8.4222   3.285  0.00148 **
# CR_1_CpG_9         60.8380    13.2005   4.609 1.41e-05 ***
# CR_2_CpG_3          0.4843     7.0274   0.069  0.94522
# CR_4_CpG_27.28.29  28.6567    14.4195   1.987  0.05010 .
# CR_12_1_CpG_3      23.2780     8.6350   2.696  0.00846 **
# CR_13_CpG_2       -25.5628     9.8768  -2.588  0.01135 *
# CR_21_CpG_11      -24.0774     5.3252  -4.521 1.97e-05 ***
# CR_23_CpG_3         6.9616     8.8770   0.784  0.43508
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 4.406 on 85 degrees of freedom
# Multiple R-squared:  0.7972,	Adjusted R-squared:  0.7805
# F-statistic: 47.74 on 7 and 85 DF,  p-value: < 2.2e-16
